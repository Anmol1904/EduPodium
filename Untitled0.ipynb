# %% [markdown]
# <a href="https://colab.research.google.com/github/Anmol1904/EduPodium/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pylab import *
x=arange(50)*2*pi/50
y=cos(x)
plot(y)
show()

# %%
from pylab import *
x=arange(50)*2*pi/50
y=sin(x)
plot(y)
show()

# %%
from pylab import *
x=arange(50)*2*pi/50
y=tan(x)
plot(y)
show()

# %%
from pylab import *
x=arange(50)*2*pi/50
scatter(x,sin(x))
show()

# %%
from pylab import *
x=arange(50)*2*pi/50
bar(x,sin(x),width=0.1)
show()

# %%
from pylab import *
x=arange(50)*2*pi/50
bar(x,sin(x),width=x[1]-x[0])
show()

# %%
from matplotlib import pyplot as plt
plt.plot([6,2,3])      #y and x wiill be index values 0,1,2....
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from matplotlib import pyplot as plt
plt.plot([6,2,3,7],[2,4,8,9])     #x y
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from matplotlib import pyplot as plt
x=[1,2,3,4]      #x
y=[5,8,7,3]      #y
plt.title("line graph")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.plot(x,y)
plt.show()
